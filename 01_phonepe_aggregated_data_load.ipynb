# %% [markdown]
# # **LOADING AGGREGATED DATA**

# %%
# !pip install pandas mysql-connector-python
# Out:
# Requirement already satisfied: pandas in c:\users\sharan\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: mysql-connector-python in c:\users\sharan\anaconda3\lib\site-packages (9.3.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sharan\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sharan\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sharan\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sharan\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\sharan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import json
import pandas as pd
import mysql.connector

# %%
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='1234', 
    database='phonepe'
)
cursor = conn.cursor()

# %%
base_path = r'C:\Users\sharan\Documents\phonepe_transaction_insights\data\pulse-master\pulse-master\data'

# %%
def load_aggregated_user():
    data = []
    path = os.path.join(base_path, 'aggregated', 'user', 'country', 'india', 'state')
    
    for state in os.listdir(path):
        state_path = os.path.join(path, state)
        for year in os.listdir(state_path):
            year_path = os.path.join(state_path, year)
            for file in os.listdir(year_path):
                file_path = os.path.join(year_path, file)
                
                # Skip non-json files
                if not file.endswith('.json'):
                    continue
                
                try:
                    quarter = int(file.strip('.json').split('-')[-1])
                except (IndexError, ValueError):
                    print(f"Skipping file (invalid name): {file}")
                    continue

                with open(file_path, 'r') as f:
                    js = json.load(f)
                    if js['data'] and js['data'].get('usersByDevice'):
                        for u in js['data']['usersByDevice']:
                            data.append({
                                'year': int(year),
                                'quarter': quarter,
                                'state': state.replace('-', ' ').title(),
                                'brand': u.get('brand'),
                                'user_count': u.get('count'),
                                'user_percentage': u.get('percentage')
                            })
    
    df = pd.DataFrame(data)

    for _, row in df.iterrows():
        cursor.execute("""
            INSERT INTO aggregated_user (year, quarter, state, brand, user_count, user_percentage)
            VALUES (%s, %s, %s, %s, %s, %s)
        """, tuple(row))
    conn.commit()
    print("aggregated_user inserted.")

# %%
load_aggregated_user()
# Out:
# aggregated_user inserted.

# %%
def load_aggregated_transaction():
    base_path = r'C:\Users\sharan\Documents\phonepe_transaction_insights\data\pulse-master\pulse-master\data'
    data = []

    # Walk through the folder structure for transaction data
    for state in os.listdir(os.path.join(base_path, 'aggregated', 'transaction', 'country', 'india', 'state')):
        state_path = os.path.join(base_path, 'aggregated', 'transaction', 'country', 'india', 'state', state)
        if not os.path.isdir(state_path):
            continue

        for year in os.listdir(state_path):
            year_path = os.path.join(state_path, year)
            if not os.path.isdir(year_path):
                continue

            for file_name in os.listdir(year_path):
                if not file_name.endswith('.json'):
                    continue

                quarter = int(file_name.strip('.json').split('-')[-1])
                file_path = os.path.join(year_path, file_name)

                with open(file_path, 'r') as f:
                    content = json.load(f)
                    for tx in content.get('data', {}).get('transactionData', []):
                        data.append({
                            'year': int(year),
                            'quarter': quarter,
                            'state': state.replace('-', ' ').title(),
                            'transaction_type': tx.get('name'),
                            'transaction_count': tx['paymentInstruments'][0].get('count'),
                            'transaction_amount': tx['paymentInstruments'][0].get('amount')
                        })

    df = pd.DataFrame(data)

    # Insert into MySQL table
    for _, row in df.iterrows():
        cursor.execute("""
            INSERT INTO aggregated_transaction 
            (year, quarter, state, transaction_type, transaction_count, transaction_amount)
            VALUES (%s, %s, %s, %s, %s, %s)
        """, tuple(row))

    conn.commit()
    print("aggregated_transaction inserted.")

# %%
load_aggregated_transaction()
# Out:
# aggregated_transaction inserted.

# %%
import os
import json

def load_aggregated_insurance(base_path, cursor, conn):
    for state in os.listdir(base_path):
        state_path = os.path.join(base_path, state)
        if not os.path.isdir(state_path):
            continue
        for year in os.listdir(state_path):
            year_path = os.path.join(state_path, year)
            if not os.path.isdir(year_path):
                continue
            for file_name in os.listdir(year_path):
                if not file_name.endswith('.json'):
                    continue
                
                quarter = int(file_name.strip('.json').split('-')[-1])  # quarter extraction
                
                file_path = os.path.join(year_path, file_name)
                with open(file_path, 'r') as f:
                    data = json.load(f)
                
                transaction_data = data.get('data', {}).get('transactionData', [])
                for entry in transaction_data:
                    if entry.get('name') == 'Insurance':
                        for payment in entry.get('paymentInstruments', []):
                            insurance_type = payment.get('type', 'Unknown')
                            insurance_count = int(payment.get('count', 0))
                            insurance_amount = float(payment.get('amount', 0))
                            
                            print(f"Inserting: year={year}, quarter={quarter}, state={state}, insurance_type={insurance_type}, count={insurance_count}, amount={insurance_amount}")
                            
                            cursor.execute("""
                                INSERT INTO aggregated_insurance
                                (year, quarter, state, insurance_type, insurance_count, insurance_amount)
                                VALUES (%s, %s, %s, %s, %s, %s)
                            """, (int(year), quarter, state, insurance_type, insurance_count, insurance_amount))
    
    conn.commit()
    print("aggregated_insurance inserted.")

# %%
base_path_insurance = r"C:\Users\sharan\Documents\phonepe_transaction_insights\data\pulse-master\pulse-master\data\aggregated\insurance\country\india\state"
load_aggregated_insurance(base_path_insurance, cursor, conn)
# Out:
# Inserting: year=2020, quarter=2, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=6, amount=1360.0
# Inserting: year=2020, quarter=3, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=41, amount=15380.0
# Inserting: year=2020, quarter=4, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=124, amount=157975.0
# Inserting: year=2021, quarter=1, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=225, amount=244266.0
# Inserting: year=2021, quarter=2, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=137, amount=181504.0
# Inserting: year=2021, quarter=3, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=230, amount=305235.0
# Inserting: year=2021, quarter=4, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=757, amount=1056380.0
# Inserting: year=2022, quarter=1, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=768, amount=1131287.0
# Inserting: year=2022, quarter=2, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=501, amount=779740.0
# Inserting: year=2022, quarter=3, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=643, amount=902466.0
# Inserting: year=2022, quarter=4, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=901, amount=1441210.0
# Inserting: year=2023, quarter=1, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=1004, amount=1439198.0
# Inserting: year=2023, quarter=2, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=768, amount=1233395.0
# Inserting: year=2023, quarter=3, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=795, amount=1251145.0
# Inserting: year=2023, quarter=4, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=1145, amount=1757821.0
# Inserting: year=2024, quarter=1, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=1371, amount=1964556.0
# Inserting: year=2024, quarter=2, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=1097, amount=1744694.0
# Inserting: year=2024, quarter=3, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=1191, amount=1752800.0
# Inserting: year=2024, quarter=4, state=andaman-&-nicobar-islands, insurance_type=TOTAL, count=1293, amount=2026380.0
# Inserting: year=2020, quarter=2, state=andhra-pradesh, insurance_type=TOTAL, count=22104, amount=3982391.0
# Inserting: year=2020, quarter=3, state=andhra-pradesh, insurance_type=TOTAL, count=49812, amount=12426481.0
# Inserting: year=2020, quarter=4, state=andhra-pradesh, insurance_type=TOTAL, count=21464, amount=12985632.0
# Inserting: year=2021, quarter=1, state=andhra-pradesh, insurance_type=TOTAL, count=22105, amount=12749874.0
# Inserting: year=2021, quarter=2, state=andhra-pradesh, insurance_type=TOTAL, count=33205, amount=22730687.0
# Inserting: year=2021, quarter=3, state=andhra-pradesh, insurance_type=TOTAL, count=23075, amount=19914338.0
# Inserting: year=2021, quarter=4, state=andhra-pradesh, insurance_type=TOTAL, count=25423, amount=31610335.0
# Inserting: year=2022, quarter=1, state=andhra-pradesh, insurance_type=TOTAL, count=29954, amount=42648157.0
# Inserting: year=2022, quarter=2, state=andhra-pradesh, insurance_type=TOTAL, count=32185, amount=41708072.0
# Inserting: year=2022, quarter=3, state=andhra-pradesh, insurance_type=TOTAL, count=39301, amount=48791931.0
# Inserting: year=2022, quarter=4, state=andhra-pradesh, insurance_type=TOTAL, count=44329, amount=58043239.0
# Inserting: year=2023, quarter=1, state=andhra-pradesh, insurance_type=TOTAL, count=34920, amount=51963355.0
# Inserting: year=2023, quarter=2, state=andhra-pradesh, insurance_type=TOTAL, count=36376, amount=52067478.0
# Inserting: year=2023, quarter=3, state=andhra-pradesh, insurance_type=TOTAL, count=43150, amount=57802396.0
# Inserting: year=2023, quarter=4, state=andhra-pradesh, insurance_type=TOTAL, count=41798, amount=62342423.0
# Inserting: year=2024, quarter=1, state=andhra-pradesh, insurance_type=TOTAL, count=46582, amount=63563802.0
# Inserting: year=2024, quarter=2, state=andhra-pradesh, insurance_type=TOTAL, count=42547, amount=62948281.0
# Inserting: year=2024, quarter=3, state=andhra-pradesh, insurance_type=TOTAL, count=48014, amount=73915199.0
# Inserting: year=2024, quarter=4, state=andhra-pradesh, insurance_type=TOTAL, count=61425, amount=80028914.0
# Inserting: year=2020, quarter=2, state=arunachal-pradesh, insurance_type=TOTAL, count=65, amount=14329.0
# Inserting: year=2020, quarter=3, state=arunachal-pradesh, insurance_type=TOTAL, count=135, amount=39687.0
# Inserting: year=2020, quarter=4, state=arunachal-pradesh, insurance_type=TOTAL, count=125, amount=84247.0
# Inserting: year=2021, quarter=1, state=arunachal-pradesh, insurance_type=TOTAL, count=194, amount=131611.0
# Inserting: year=2021, quarter=2, state=arunachal-pradesh, insurance_type=TOTAL, count=204, amount=224928.0
# Inserting: year=2021, quarter=3, state=arunachal-pradesh, insurance_type=TOTAL, count=212, amount=371051.0
# Inserting: year=2021, quarter=4, state=arunachal-pradesh, insurance_type=TOTAL, count=320, amount=598459.0
# Inserting: year=2022, quarter=1, state=arunachal-pradesh, insurance_type=TOTAL, count=355, amount=894107.0
# Inserting: year=2022, quarter=2, state=arunachal-pradesh, insurance_type=TOTAL, count=564, amount=1360231.0
# Inserting: year=2022, quarter=3, state=arunachal-pradesh, insurance_type=TOTAL, count=510, amount=1300304.0
# Inserting: year=2022, quarter=4, state=arunachal-pradesh, insurance_type=TOTAL, count=613, amount=1464572.0
# Inserting: year=2023, quarter=1, state=arunachal-pradesh, insurance_type=TOTAL, count=606, amount=1747475.0
# Inserting: year=2023, quarter=2, state=arunachal-pradesh, insurance_type=TOTAL, count=696, amount=2095988.0
# Inserting: year=2023, quarter=3, state=arunachal-pradesh, insurance_type=TOTAL, count=718, amount=1904786.0
# Inserting: year=2023, quarter=4, state=arunachal-pradesh, insurance_type=TOTAL, count=809, amount=2105408.0
# Inserting: year=2024, quarter=1, state=arunachal-pradesh, insurance_type=TOTAL, count=1100, amount=2419700.0
# Inserting: year=2024, quarter=2, state=arunachal-pradesh, insurance_type=TOTAL, count=1147, amount=2353015.0
# Inserting: year=2024, quarter=3, state=arunachal-pradesh, insurance_type=TOTAL, count=842, amount=1951385.0
# Inserting: year=2024, quarter=4, state=arunachal-pradesh, insurance_type=TOTAL, count=999, amount=2359472.0
# Inserting: year=2020, quarter=2, state=assam, insurance_type=TOTAL, count=978, amount=210034.0
# Inserting: year=2020, quarter=3, state=assam, insurance_type=TOTAL, count=2206, amount=599450.0
# Inserting: year=2020, quarter=4, state=assam, insurance_type=TOTAL, count=2413, amount=1806801.0
# Inserting: year=2021, quarter=1, state=assam, insurance_type=TOTAL, count=3167, amount=2334419.0
# Inserting: year=2021, quarter=2, state=assam, insurance_type=TOTAL, count=3265, amount=3008122.0
# Inserting: year=2021, quarter=3, state=assam, insurance_type=TOTAL, count=4495, amount=6010865.0
# Inserting: year=2021, quarter=4, state=assam, insurance_type=TOTAL, count=8622, amount=13962068.0
# Inserting: year=2022, quarter=1, state=assam, insurance_type=TOTAL, count=16230, amount=27447766.0
# Inserting: year=2022, quarter=2, state=assam, insurance_type=TOTAL, count=9228, amount=15357811.0
# Inserting: year=2022, quarter=3, state=assam, insurance_type=TOTAL, count=14149, amount=22543564.0
# Inserting: year=2022, quarter=4, state=assam, insurance_type=TOTAL, count=18826, amount=29239168.0
# Inserting: year=2023, quarter=1, state=assam, insurance_type=TOTAL, count=22100, amount=36963888.0
# Inserting: year=2023, quarter=2, state=assam, insurance_type=TOTAL, count=16475, amount=28368139.0
# Inserting: year=2023, quarter=3, state=assam, insurance_type=TOTAL, count=22593, amount=35618158.0
# Inserting: year=2023, quarter=4, state=assam, insurance_type=TOTAL, count=23168, amount=38731734.0
# Inserting: year=2024, quarter=1, state=assam, insurance_type=TOTAL, count=33097, amount=48107248.0
# Inserting: year=2024, quarter=2, state=assam, insurance_type=TOTAL, count=22368, amount=34796603.0
# Inserting: year=2024, quarter=3, state=assam, insurance_type=TOTAL, count=17633, amount=31388971.0
# Inserting: year=2024, quarter=4, state=assam, insurance_type=TOTAL, count=21805, amount=35336229.0
# Inserting: year=2020, quarter=2, state=bihar, insurance_type=TOTAL, count=2816, amount=595621.0
# Inserting: year=2020, quarter=3, state=bihar, insurance_type=TOTAL, count=9733, amount=2161102.0
# Inserting: year=2020, quarter=4, state=bihar, insurance_type=TOTAL, count=9913, amount=7860932.0
# Inserting: year=2021, quarter=1, state=bihar, insurance_type=TOTAL, count=12554, amount=8796619.0
# Inserting: year=2021, quarter=2, state=bihar, insurance_type=TOTAL, count=14301, amount=13301581.0
# Inserting: year=2021, quarter=3, state=bihar, insurance_type=TOTAL, count=18030, amount=18234941.0
# Inserting: year=2021, quarter=4, state=bihar, insurance_type=TOTAL, count=22456, amount=27313813.0
# Inserting: year=2022, quarter=1, state=bihar, insurance_type=TOTAL, count=20253, amount=27755736.0
# Inserting: year=2022, quarter=2, state=bihar, insurance_type=TOTAL, count=21892, amount=28212833.0
# Inserting: year=2022, quarter=3, state=bihar, insurance_type=TOTAL, count=28511, amount=34704251.0
# Inserting: year=2022, quarter=4, state=bihar, insurance_type=TOTAL, count=33895, amount=43914519.0
# Inserting: year=2023, quarter=1, state=bihar, insurance_type=TOTAL, count=26929, amount=38746711.0
# Inserting: year=2023, quarter=2, state=bihar, insurance_type=TOTAL, count=29212, amount=40354886.0
# Inserting: year=2023, quarter=3, state=bihar, insurance_type=TOTAL, count=36550, amount=45832355.0
# Inserting: year=2023, quarter=4, state=bihar, insurance_type=TOTAL, count=41447, amount=57624322.0
# Inserting: year=2024, quarter=1, state=bihar, insurance_type=TOTAL, count=51592, amount=63844442.0
# Inserting: year=2024, quarter=2, state=bihar, insurance_type=TOTAL, count=49101, amount=65285065.0
# Inserting: year=2024, quarter=3, state=bihar, insurance_type=TOTAL, count=44745, amount=62777286.0
# Inserting: year=2024, quarter=4, state=bihar, insurance_type=TOTAL, count=62662, amount=83739800.0
# Inserting: year=2020, quarter=2, state=chandigarh, insurance_type=TOTAL, count=149, amount=29537.0
# Inserting: year=2020, quarter=3, state=chandigarh, insurance_type=TOTAL, count=264, amount=70969.0
# Inserting: year=2020, quarter=4, state=chandigarh, insurance_type=TOTAL, count=200, amount=153341.0
# Inserting: year=2021, quarter=1, state=chandigarh, insurance_type=TOTAL, count=338, amount=238576.0
# Inserting: year=2021, quarter=2, state=chandigarh, insurance_type=TOTAL, count=378, amount=310943.0
# Inserting: year=2021, quarter=3, state=chandigarh, insurance_type=TOTAL, count=494, amount=469634.0
# Inserting: year=2021, quarter=4, state=chandigarh, insurance_type=TOTAL, count=710, amount=835813.0
# Inserting: year=2022, quarter=1, state=chandigarh, insurance_type=TOTAL, count=792, amount=1150932.0
# Inserting: year=2022, quarter=2, state=chandigarh, insurance_type=TOTAL, count=1330, amount=1874959.0
# Inserting: year=2022, quarter=3, state=chandigarh, insurance_type=TOTAL, count=1533, amount=1998439.0
# Inserting: year=2022, quarter=4, state=chandigarh, insurance_type=TOTAL, count=1403, amount=2024528.0
# Inserting: year=2023, quarter=1, state=chandigarh, insurance_type=TOTAL, count=1520, amount=2415574.0
# Inserting: year=2023, quarter=2, state=chandigarh, insurance_type=TOTAL, count=1704, amount=2501107.0
# Inserting: year=2023, quarter=3, state=chandigarh, insurance_type=TOTAL, count=1883, amount=2660630.0
# Inserting: year=2023, quarter=4, state=chandigarh, insurance_type=TOTAL, count=1767, amount=3053934.0
# Inserting: year=2024, quarter=1, state=chandigarh, insurance_type=TOTAL, count=1730, amount=3143984.0
# Inserting: year=2024, quarter=2, state=chandigarh, insurance_type=TOTAL, count=1798, amount=3177315.0
# Inserting: year=2024, quarter=3, state=chandigarh, insurance_type=TOTAL, count=1991, amount=3445738.0
# Inserting: year=2024, quarter=4, state=chandigarh, insurance_type=TOTAL, count=2095, amount=3729932.0
# Inserting: year=2020, quarter=2, state=chhattisgarh, insurance_type=TOTAL, count=1346, amount=279005.0
# Inserting: year=2020, quarter=3, state=chhattisgarh, insurance_type=TOTAL, count=4702, amount=1393656.0
# Inserting: year=2020, quarter=4, state=chhattisgarh, insurance_type=TOTAL, count=3757, amount=2249901.0
# Inserting: year=2021, quarter=1, state=chhattisgarh, insurance_type=TOTAL, count=4712, amount=2620468.0
# Inserting: year=2021, quarter=2, state=chhattisgarh, insurance_type=TOTAL, count=5055, amount=3813417.0
# Inserting: year=2021, quarter=3, state=chhattisgarh, insurance_type=TOTAL, count=4676, amount=3568837.0
# Inserting: year=2021, quarter=4, state=chhattisgarh, insurance_type=TOTAL, count=6029, amount=8229039.0
# Inserting: year=2022, quarter=1, state=chhattisgarh, insurance_type=TOTAL, count=6612, amount=10139190.0
# Inserting: year=2022, quarter=2, state=chhattisgarh, insurance_type=TOTAL, count=7008, amount=10119964.0
# Inserting: year=2022, quarter=3, state=chhattisgarh, insurance_type=TOTAL, count=8849, amount=12119470.0
# Inserting: year=2022, quarter=4, state=chhattisgarh, insurance_type=TOTAL, count=11994, amount=18137856.0
# Inserting: year=2023, quarter=1, state=chhattisgarh, insurance_type=TOTAL, count=10460, amount=16577191.0
# Inserting: year=2023, quarter=2, state=chhattisgarh, insurance_type=TOTAL, count=10514, amount=16389610.0
# Inserting: year=2023, quarter=3, state=chhattisgarh, insurance_type=TOTAL, count=11927, amount=17838382.0
# Inserting: year=2023, quarter=4, state=chhattisgarh, insurance_type=TOTAL, count=17300, amount=29704673.0
# Inserting: year=2024, quarter=1, state=chhattisgarh, insurance_type=TOTAL, count=19579, amount=30083259.0
# Inserting: year=2024, quarter=2, state=chhattisgarh, insurance_type=TOTAL, count=15724, amount=25935743.0
# Inserting: year=2024, quarter=3, state=chhattisgarh, insurance_type=TOTAL, count=16550, amount=27724060.0
# Inserting: year=2024, quarter=4, state=chhattisgarh, insurance_type=TOTAL, count=22723, amount=37421165.0
# Inserting: year=2020, quarter=2, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=651, amount=101029.0
# Inserting: year=2020, quarter=3, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=257, amount=65504.0
# Inserting: year=2020, quarter=4, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=232, amount=149513.0
# Inserting: year=2021, quarter=1, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=467, amount=285691.0
# Inserting: year=2021, quarter=2, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=368, amount=275638.0
# Inserting: year=2021, quarter=3, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=360, amount=273596.0
# Inserting: year=2021, quarter=4, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=421, amount=425384.0
# Inserting: year=2022, quarter=1, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=493, amount=720741.0
# Inserting: year=2022, quarter=2, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=438, amount=686857.0
# Inserting: year=2022, quarter=3, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=707, amount=983776.0
# Inserting: year=2022, quarter=4, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=871, amount=1272628.0
# Inserting: year=2023, quarter=1, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=799, amount=1215168.0
# Inserting: year=2023, quarter=2, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=694, amount=1058753.0
# Inserting: year=2023, quarter=3, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=969, amount=1333103.0
# Inserting: year=2023, quarter=4, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=1207, amount=1973867.0
# Inserting: year=2024, quarter=1, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=1295, amount=1908509.0
# Inserting: year=2024, quarter=2, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=1008, amount=1367259.0
# Inserting: year=2024, quarter=3, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=1052, amount=1602869.0
# Inserting: year=2024, quarter=4, state=dadra-&-nagar-haveli-&-daman-&-diu, insurance_type=TOTAL, count=1503, amount=2292529.0
# Inserting: year=2020, quarter=2, state=delhi, insurance_type=TOTAL, count=11716, amount=1897480.0
# Inserting: year=2020, quarter=3, state=delhi, insurance_type=TOTAL, count=7588, amount=1927285.0
# Inserting: year=2020, quarter=4, state=delhi, insurance_type=TOTAL, count=9725, amount=8045442.0
# Inserting: year=2021, quarter=1, state=delhi, insurance_type=TOTAL, count=12822, amount=9655261.0
# Inserting: year=2021, quarter=2, state=delhi, insurance_type=TOTAL, count=13292, amount=10840929.0
# Inserting: year=2021, quarter=3, state=delhi, insurance_type=TOTAL, count=16679, amount=15007079.0
# Inserting: year=2021, quarter=4, state=delhi, insurance_type=TOTAL, count=34251, amount=36578331.0
# Inserting: year=2022, quarter=1, state=delhi, insurance_type=TOTAL, count=28232, amount=35442069.0
# Inserting: year=2022, quarter=2, state=delhi, insurance_type=TOTAL, count=26378, amount=31787281.0
# Inserting: year=2022, quarter=3, state=delhi, insurance_type=TOTAL, count=35944, amount=41570160.0
# Inserting: year=2022, quarter=4, state=delhi, insurance_type=TOTAL, count=48908, amount=60603173.0
# Inserting: year=2023, quarter=1, state=delhi, insurance_type=TOTAL, count=45821, amount=61040038.0
# Inserting: year=2023, quarter=2, state=delhi, insurance_type=TOTAL, count=41358, amount=54951108.0
# Inserting: year=2023, quarter=3, state=delhi, insurance_type=TOTAL, count=47113, amount=58878500.0
# Inserting: year=2023, quarter=4, state=delhi, insurance_type=TOTAL, count=56336, amount=77332401.0
# Inserting: year=2024, quarter=1, state=delhi, insurance_type=TOTAL, count=53050, amount=76232346.0
# Inserting: year=2024, quarter=2, state=delhi, insurance_type=TOTAL, count=46189, amount=68046072.0
# Inserting: year=2024, quarter=3, state=delhi, insurance_type=TOTAL, count=49150, amount=71139489.0
# Inserting: year=2024, quarter=4, state=delhi, insurance_type=TOTAL, count=67962, amount=94390728.0
# Inserting: year=2020, quarter=2, state=goa, insurance_type=TOTAL, count=341, amount=71100.0
# Inserting: year=2020, quarter=3, state=goa, insurance_type=TOTAL, count=683, amount=196864.0
# Inserting: year=2020, quarter=4, state=goa, insurance_type=TOTAL, count=614, amount=682364.0
# Inserting: year=2021, quarter=1, state=goa, insurance_type=TOTAL, count=879, amount=827384.0
# Inserting: year=2021, quarter=2, state=goa, insurance_type=TOTAL, count=1016, amount=1028339.0
# Inserting: year=2021, quarter=3, state=goa, insurance_type=TOTAL, count=1214, amount=1385986.0
# Inserting: year=2021, quarter=4, state=goa, insurance_type=TOTAL, count=2087, amount=2737316.0
# Inserting: year=2022, quarter=1, state=goa, insurance_type=TOTAL, count=2634, amount=3865245.0
# Inserting: year=2022, quarter=2, state=goa, insurance_type=TOTAL, count=3524, amount=5093510.0
# Inserting: year=2022, quarter=3, state=goa, insurance_type=TOTAL, count=3157, amount=4142108.0
# Inserting: year=2022, quarter=4, state=goa, insurance_type=TOTAL, count=4388, amount=6190669.0
# Inserting: year=2023, quarter=1, state=goa, insurance_type=TOTAL, count=4097, amount=5859549.0
# Inserting: year=2023, quarter=2, state=goa, insurance_type=TOTAL, count=4166, amount=5930801.0
# Inserting: year=2023, quarter=3, state=goa, insurance_type=TOTAL, count=3927, amount=5646054.0
# Inserting: year=2023, quarter=4, state=goa, insurance_type=TOTAL, count=4883, amount=7411001.0
# Inserting: year=2024, quarter=1, state=goa, insurance_type=TOTAL, count=5225, amount=7528093.0
# Inserting: year=2024, quarter=2, state=goa, insurance_type=TOTAL, count=5021, amount=7178558.0
# Inserting: year=2024, quarter=3, state=goa, insurance_type=TOTAL, count=5354, amount=8051690.0
# Inserting: year=2024, quarter=4, state=goa, insurance_type=TOTAL, count=6662, amount=9903374.0
# Inserting: year=2020, quarter=2, state=gujarat, insurance_type=TOTAL, count=7697, amount=1430591.0
# Inserting: year=2020, quarter=3, state=gujarat, insurance_type=TOTAL, count=12525, amount=3335812.0
# Inserting: year=2020, quarter=4, state=gujarat, insurance_type=TOTAL, count=9990, amount=6055037.0
# Inserting: year=2021, quarter=1, state=gujarat, insurance_type=TOTAL, count=12673, amount=7288104.0
# Inserting: year=2021, quarter=2, state=gujarat, insurance_type=TOTAL, count=14676, amount=10263998.0
# Inserting: year=2021, quarter=3, state=gujarat, insurance_type=TOTAL, count=15348, amount=12341903.0
# Inserting: year=2021, quarter=4, state=gujarat, insurance_type=TOTAL, count=19142, amount=23282921.0
# Inserting: year=2022, quarter=1, state=gujarat, insurance_type=TOTAL, count=22221, amount=29953433.0
# Inserting: year=2022, quarter=2, state=gujarat, insurance_type=TOTAL, count=25381, amount=32090965.0
# Inserting: year=2022, quarter=3, state=gujarat, insurance_type=TOTAL, count=31302, amount=37557227.0
# Inserting: year=2022, quarter=4, state=gujarat, insurance_type=TOTAL, count=36418, amount=50629325.0
# Inserting: year=2023, quarter=1, state=gujarat, insurance_type=TOTAL, count=32600, amount=46937694.0
# Inserting: year=2023, quarter=2, state=gujarat, insurance_type=TOTAL, count=32484, amount=46254095.0
# Inserting: year=2023, quarter=3, state=gujarat, insurance_type=TOTAL, count=51049, amount=65768085.0
# Inserting: year=2023, quarter=4, state=gujarat, insurance_type=TOTAL, count=41128, amount=66735446.0
# Inserting: year=2024, quarter=1, state=gujarat, insurance_type=TOTAL, count=44665, amount=62633910.0
# Inserting: year=2024, quarter=2, state=gujarat, insurance_type=TOTAL, count=44007, amount=63866463.0
# Inserting: year=2024, quarter=3, state=gujarat, insurance_type=TOTAL, count=46763, amount=70950327.0
# Inserting: year=2024, quarter=4, state=gujarat, insurance_type=TOTAL, count=62526, amount=91858105.0
# Inserting: year=2020, quarter=2, state=haryana, insurance_type=TOTAL, count=6321, amount=1179814.0
# Inserting: year=2020, quarter=3, state=haryana, insurance_type=TOTAL, count=7139, amount=1884868.0
# Inserting: year=2020, quarter=4, state=haryana, insurance_type=TOTAL, count=8283, amount=5974278.0
# Inserting: year=2021, quarter=1, state=haryana, insurance_type=TOTAL, count=11038, amount=7297880.0
# Inserting: year=2021, quarter=2, state=haryana, insurance_type=TOTAL, count=12516, amount=11272453.0
# Inserting: year=2021, quarter=3, state=haryana, insurance_type=TOTAL, count=14163, amount=13215898.0
# Inserting: year=2021, quarter=4, state=haryana, insurance_type=TOTAL, count=19489, amount=25885838.0
# Inserting: year=2022, quarter=1, state=haryana, insurance_type=TOTAL, count=22783, amount=32526943.0
# Inserting: year=2022, quarter=2, state=haryana, insurance_type=TOTAL, count=25352, amount=33759068.0
# Inserting: year=2022, quarter=3, state=haryana, insurance_type=TOTAL, count=35346, amount=45402800.0
# Inserting: year=2022, quarter=4, state=haryana, insurance_type=TOTAL, count=37971, amount=56627115.0
# Inserting: year=2023, quarter=1, state=haryana, insurance_type=TOTAL, count=37287, amount=61127194.0
# Inserting: year=2023, quarter=2, state=haryana, insurance_type=TOTAL, count=40710, amount=62186066.0
# Inserting: year=2023, quarter=3, state=haryana, insurance_type=TOTAL, count=42815, amount=61782311.0
# Inserting: year=2023, quarter=4, state=haryana, insurance_type=TOTAL, count=47506, amount=80747159.0
# Inserting: year=2024, quarter=1, state=haryana, insurance_type=TOTAL, count=50391, amount=81816509.0
# Inserting: year=2024, quarter=2, state=haryana, insurance_type=TOTAL, count=46085, amount=74779879.0
# Inserting: year=2024, quarter=3, state=haryana, insurance_type=TOTAL, count=49735, amount=79198642.0
# Inserting: year=2024, quarter=4, state=haryana, insurance_type=TOTAL, count=58808, amount=94316512.0
# Inserting: year=2020, quarter=2, state=himachal-pradesh, insurance_type=TOTAL, count=392, amount=77936.0
# Inserting: year=2020, quarter=3, state=himachal-pradesh, insurance_type=TOTAL, count=531, amount=165559.0
# Inserting: year=2020, quarter=4, state=himachal-pradesh, insurance_type=TOTAL, count=710, amount=630966.0
# Inserting: year=2021, quarter=1, state=himachal-pradesh, insurance_type=TOTAL, count=1064, amount=906492.0
# Inserting: year=2021, quarter=2, state=himachal-pradesh, insurance_type=TOTAL, count=1210, amount=1402338.0
# Inserting: year=2021, quarter=3, state=himachal-pradesh, insurance_type=TOTAL, count=1759, amount=2444545.0
# Inserting: year=2021, quarter=4, state=himachal-pradesh, insurance_type=TOTAL, count=2474, amount=4667661.0
# Inserting: year=2022, quarter=1, state=himachal-pradesh, insurance_type=TOTAL, count=2768, amount=5234739.0
# Inserting: year=2022, quarter=2, state=himachal-pradesh, insurance_type=TOTAL, count=2831, amount=5371078.0
# Inserting: year=2022, quarter=3, state=himachal-pradesh, insurance_type=TOTAL, count=3641, amount=6161692.0
# Inserting: year=2022, quarter=4, state=himachal-pradesh, insurance_type=TOTAL, count=4565, amount=9060436.0
# Inserting: year=2023, quarter=1, state=himachal-pradesh, insurance_type=TOTAL, count=3909, amount=7826133.0
# Inserting: year=2023, quarter=2, state=himachal-pradesh, insurance_type=TOTAL, count=4197, amount=8499425.0
# Inserting: year=2023, quarter=3, state=himachal-pradesh, insurance_type=TOTAL, count=3935, amount=7869767.0
# Inserting: year=2023, quarter=4, state=himachal-pradesh, insurance_type=TOTAL, count=5211, amount=11898824.0
# Inserting: year=2024, quarter=1, state=himachal-pradesh, insurance_type=TOTAL, count=5430, amount=10433254.0
# Inserting: year=2024, quarter=2, state=himachal-pradesh, insurance_type=TOTAL, count=5194, amount=10008705.0
# Inserting: year=2024, quarter=3, state=himachal-pradesh, insurance_type=TOTAL, count=5272, amount=10538999.0
# Inserting: year=2024, quarter=4, state=himachal-pradesh, insurance_type=TOTAL, count=6697, amount=14090523.0
# Inserting: year=2020, quarter=2, state=jammu-&-kashmir, insurance_type=TOTAL, count=206, amount=48484.0
# Inserting: year=2020, quarter=3, state=jammu-&-kashmir, insurance_type=TOTAL, count=441, amount=133339.0
# Inserting: year=2020, quarter=4, state=jammu-&-kashmir, insurance_type=TOTAL, count=647, amount=734861.0
# Inserting: year=2021, quarter=1, state=jammu-&-kashmir, insurance_type=TOTAL, count=1105, amount=1546288.0
# Inserting: year=2021, quarter=2, state=jammu-&-kashmir, insurance_type=TOTAL, count=1197, amount=1832089.0
# Inserting: year=2021, quarter=3, state=jammu-&-kashmir, insurance_type=TOTAL, count=1452, amount=2139133.0
# Inserting: year=2021, quarter=4, state=jammu-&-kashmir, insurance_type=TOTAL, count=3113, amount=5223317.0
# Inserting: year=2022, quarter=1, state=jammu-&-kashmir, insurance_type=TOTAL, count=3584, amount=7244267.0
# Inserting: year=2022, quarter=2, state=jammu-&-kashmir, insurance_type=TOTAL, count=4071, amount=7729792.0
# Inserting: year=2022, quarter=3, state=jammu-&-kashmir, insurance_type=TOTAL, count=4794, amount=8281826.0
# Inserting: year=2022, quarter=4, state=jammu-&-kashmir, insurance_type=TOTAL, count=5031, amount=10111183.0
# Inserting: year=2023, quarter=1, state=jammu-&-kashmir, insurance_type=TOTAL, count=4555, amount=10275877.0
# Inserting: year=2023, quarter=2, state=jammu-&-kashmir, insurance_type=TOTAL, count=5262, amount=10974839.0
# Inserting: year=2023, quarter=3, state=jammu-&-kashmir, insurance_type=TOTAL, count=5453, amount=10975874.0
# Inserting: year=2023, quarter=4, state=jammu-&-kashmir, insurance_type=TOTAL, count=6264, amount=13932309.0
# Inserting: year=2024, quarter=1, state=jammu-&-kashmir, insurance_type=TOTAL, count=7313, amount=14695182.0
# Inserting: year=2024, quarter=2, state=jammu-&-kashmir, insurance_type=TOTAL, count=7397, amount=14237707.0
# Inserting: year=2024, quarter=3, state=jammu-&-kashmir, insurance_type=TOTAL, count=7597, amount=15554635.0
# Inserting: year=2024, quarter=4, state=jammu-&-kashmir, insurance_type=TOTAL, count=8893, amount=18252110.0
# Inserting: year=2020, quarter=2, state=jharkhand, insurance_type=TOTAL, count=2063, amount=405031.0
# Inserting: year=2020, quarter=3, state=jharkhand, insurance_type=TOTAL, count=5368, amount=1349934.0
# Inserting: year=2020, quarter=4, state=jharkhand, insurance_type=TOTAL, count=3659, amount=2857024.0
# Inserting: year=2021, quarter=1, state=jharkhand, insurance_type=TOTAL, count=4879, amount=3274851.0
# Inserting: year=2021, quarter=2, state=jharkhand, insurance_type=TOTAL, count=5180, amount=5084230.0
# Inserting: year=2021, quarter=3, state=jharkhand, insurance_type=TOTAL, count=6794, amount=7046048.0
# Inserting: year=2021, quarter=4, state=jharkhand, insurance_type=TOTAL, count=8465, amount=11190423.0
# Inserting: year=2022, quarter=1, state=jharkhand, insurance_type=TOTAL, count=9373, amount=13819466.0
# Inserting: year=2022, quarter=2, state=jharkhand, insurance_type=TOTAL, count=9477, amount=13464840.0
# Inserting: year=2022, quarter=3, state=jharkhand, insurance_type=TOTAL, count=14388, amount=18156857.0
# Inserting: year=2022, quarter=4, state=jharkhand, insurance_type=TOTAL, count=16779, amount=23147805.0
# Inserting: year=2023, quarter=1, state=jharkhand, insurance_type=TOTAL, count=16108, amount=23823406.0
# Inserting: year=2023, quarter=2, state=jharkhand, insurance_type=TOTAL, count=16662, amount=23216215.0
# Inserting: year=2023, quarter=3, state=jharkhand, insurance_type=TOTAL, count=19478, amount=25165702.0
# Inserting: year=2023, quarter=4, state=jharkhand, insurance_type=TOTAL, count=22398, amount=33484644.0
# Inserting: year=2024, quarter=1, state=jharkhand, insurance_type=TOTAL, count=24824, amount=34332990.0
# Inserting: year=2024, quarter=2, state=jharkhand, insurance_type=TOTAL, count=22224, amount=32245129.0
# Inserting: year=2024, quarter=3, state=jharkhand, insurance_type=TOTAL, count=23629, amount=34353146.0
# Inserting: year=2024, quarter=4, state=jharkhand, insurance_type=TOTAL, count=29079, amount=42253614.0
# Inserting: year=2020, quarter=2, state=karnataka, insurance_type=TOTAL, count=27358, amount=4794150.0
# Inserting: year=2020, quarter=3, state=karnataka, insurance_type=TOTAL, count=53701, amount=12407394.0
# Inserting: year=2020, quarter=4, state=karnataka, insurance_type=TOTAL, count=31747, amount=26814968.0
# Inserting: year=2021, quarter=1, state=karnataka, insurance_type=TOTAL, count=37595, amount=30183325.0
# Inserting: year=2021, quarter=2, state=karnataka, insurance_type=TOTAL, count=40969, amount=39501006.0
# Inserting: year=2021, quarter=3, state=karnataka, insurance_type=TOTAL, count=47468, amount=48078366.0
# Inserting: year=2021, quarter=4, state=karnataka, insurance_type=TOTAL, count=74436, amount=90723288.0
# Inserting: year=2022, quarter=1, state=karnataka, insurance_type=TOTAL, count=95640, amount=130733580.0
# Inserting: year=2022, quarter=2, state=karnataka, insurance_type=TOTAL, count=93385, amount=123228632.0
# Inserting: year=2022, quarter=3, state=karnataka, insurance_type=TOTAL, count=110273, amount=144605784.0
# Inserting: year=2022, quarter=4, state=karnataka, insurance_type=TOTAL, count=133971, amount=185063287.0
# Inserting: year=2023, quarter=1, state=karnataka, insurance_type=TOTAL, count=127376, amount=186543426.0
# Inserting: year=2023, quarter=2, state=karnataka, insurance_type=TOTAL, count=117232, amount=175704013.0
# Inserting: year=2023, quarter=3, state=karnataka, insurance_type=TOTAL, count=139699, amount=199448538.0
# Inserting: year=2023, quarter=4, state=karnataka, insurance_type=TOTAL, count=156076, amount=248056311.0
# Inserting: year=2024, quarter=1, state=karnataka, insurance_type=TOTAL, count=169357, amount=264708700.0
# Inserting: year=2024, quarter=2, state=karnataka, insurance_type=TOTAL, count=142599, amount=239304982.0
# Inserting: year=2024, quarter=3, state=karnataka, insurance_type=TOTAL, count=174990, amount=287393291.0
# Inserting: year=2024, quarter=4, state=karnataka, insurance_type=TOTAL, count=183532, amount=305861806.0
# Inserting: year=2020, quarter=2, state=kerala, insurance_type=TOTAL, count=1588, amount=360216.0
# Inserting: year=2020, quarter=3, state=kerala, insurance_type=TOTAL, count=8811, amount=2830361.0
# Inserting: year=2020, quarter=4, state=kerala, insurance_type=TOTAL, count=5479, amount=4445525.0
# Inserting: year=2021, quarter=1, state=kerala, insurance_type=TOTAL, count=5731, amount=5040506.0
# Inserting: year=2021, quarter=2, state=kerala, insurance_type=TOTAL, count=9530, amount=9676588.0
# Inserting: year=2021, quarter=3, state=kerala, insurance_type=TOTAL, count=10926, amount=13255646.0
# Inserting: year=2021, quarter=4, state=kerala, insurance_type=TOTAL, count=19199, amount=31260319.0
# Inserting: year=2022, quarter=1, state=kerala, insurance_type=TOTAL, count=37110, amount=64172190.0
# Inserting: year=2022, quarter=2, state=kerala, insurance_type=TOTAL, count=35667, amount=59920203.0
# Inserting: year=2022, quarter=3, state=kerala, insurance_type=TOTAL, count=54587, amount=85390924.0
# Inserting: year=2022, quarter=4, state=kerala, insurance_type=TOTAL, count=65563, amount=103982997.0
# Inserting: year=2023, quarter=1, state=kerala, insurance_type=TOTAL, count=62377, amount=101786828.0
# Inserting: year=2023, quarter=2, state=kerala, insurance_type=TOTAL, count=61032, amount=100620604.0
# Inserting: year=2023, quarter=3, state=kerala, insurance_type=TOTAL, count=66059, amount=110021582.0
# Inserting: year=2023, quarter=4, state=kerala, insurance_type=TOTAL, count=73543, amount=121905046.0
# Inserting: year=2024, quarter=1, state=kerala, insurance_type=TOTAL, count=73106, amount=115101791.0
# Inserting: year=2024, quarter=2, state=kerala, insurance_type=TOTAL, count=65271, amount=108142369.0
# Inserting: year=2024, quarter=3, state=kerala, insurance_type=TOTAL, count=79123, amount=131721699.0
# Inserting: year=2024, quarter=4, state=kerala, insurance_type=TOTAL, count=89533, amount=144083113.0
# Inserting: year=2020, quarter=2, state=ladakh, insurance_type=TOTAL, count=14, amount=2538.0
# Inserting: year=2020, quarter=3, state=ladakh, insurance_type=TOTAL, count=33, amount=10260.0
# Inserting: year=2020, quarter=4, state=ladakh, insurance_type=TOTAL, count=27, amount=34206.0
# Inserting: year=2021, quarter=1, state=ladakh, insurance_type=TOTAL, count=32, amount=34530.0
# Inserting: year=2021, quarter=2, state=ladakh, insurance_type=TOTAL, count=46, amount=86251.0
# Inserting: year=2021, quarter=3, state=ladakh, insurance_type=TOTAL, count=192, amount=174052.0
# Inserting: year=2021, quarter=4, state=ladakh, insurance_type=TOTAL, count=76, amount=195966.0
# Inserting: year=2022, quarter=1, state=ladakh, insurance_type=TOTAL, count=75, amount=193935.0
# Inserting: year=2022, quarter=2, state=ladakh, insurance_type=TOTAL, count=113, amount=269446.0
# Inserting: year=2022, quarter=3, state=ladakh, insurance_type=TOTAL, count=137, amount=369742.0
# Inserting: year=2022, quarter=4, state=ladakh, insurance_type=TOTAL, count=162, amount=410091.0
# Inserting: year=2023, quarter=1, state=ladakh, insurance_type=TOTAL, count=161, amount=495736.0
# Inserting: year=2023, quarter=2, state=ladakh, insurance_type=TOTAL, count=215, amount=635831.0
# Inserting: year=2023, quarter=3, state=ladakh, insurance_type=TOTAL, count=232, amount=649027.0
# Inserting: year=2023, quarter=4, state=ladakh, insurance_type=TOTAL, count=242, amount=718967.0
# Inserting: year=2024, quarter=1, state=ladakh, insurance_type=TOTAL, count=291, amount=614435.0
# Inserting: year=2024, quarter=2, state=ladakh, insurance_type=TOTAL, count=415, amount=964349.0
# Inserting: year=2024, quarter=3, state=ladakh, insurance_type=TOTAL, count=446, amount=978637.0
# Inserting: year=2024, quarter=4, state=ladakh, insurance_type=TOTAL, count=429, amount=970334.0
# Inserting: year=2020, quarter=3, state=lakshadweep, insurance_type=TOTAL, count=4, amount=1199.0
# Inserting: year=2021, quarter=1, state=lakshadweep, insurance_type=TOTAL, count=4, amount=5225.0
# Inserting: year=2021, quarter=2, state=lakshadweep, insurance_type=TOTAL, count=5, amount=6962.0
# Inserting: year=2021, quarter=3, state=lakshadweep, insurance_type=TOTAL, count=19, amount=16034.0
# Inserting: year=2021, quarter=4, state=lakshadweep, insurance_type=TOTAL, count=11, amount=17096.0
# Inserting: year=2022, quarter=1, state=lakshadweep, insurance_type=TOTAL, count=27, amount=34664.0
# Inserting: year=2022, quarter=2, state=lakshadweep, insurance_type=TOTAL, count=18, amount=27463.0
# Inserting: year=2022, quarter=3, state=lakshadweep, insurance_type=TOTAL, count=38, amount=41504.0
# Inserting: year=2022, quarter=4, state=lakshadweep, insurance_type=TOTAL, count=15, amount=27135.0
# Inserting: year=2023, quarter=1, state=lakshadweep, insurance_type=TOTAL, count=26, amount=30199.0
# Inserting: year=2023, quarter=2, state=lakshadweep, insurance_type=TOTAL, count=15, amount=38384.0
# Inserting: year=2023, quarter=3, state=lakshadweep, insurance_type=TOTAL, count=12, amount=12407.0
# Inserting: year=2023, quarter=4, state=lakshadweep, insurance_type=TOTAL, count=53, amount=78346.0
# Inserting: year=2024, quarter=1, state=lakshadweep, insurance_type=TOTAL, count=15, amount=12935.0
# Inserting: year=2024, quarter=2, state=lakshadweep, insurance_type=TOTAL, count=26, amount=33630.0
# Inserting: year=2024, quarter=3, state=lakshadweep, insurance_type=TOTAL, count=49, amount=55312.0
# Inserting: year=2024, quarter=4, state=lakshadweep, insurance_type=TOTAL, count=159, amount=185542.0
# Inserting: year=2020, quarter=2, state=madhya-pradesh, insurance_type=TOTAL, count=6283, amount=1198701.0
# Inserting: year=2020, quarter=3, state=madhya-pradesh, insurance_type=TOTAL, count=14476, amount=3496126.0
# Inserting: year=2020, quarter=4, state=madhya-pradesh, insurance_type=TOTAL, count=10653, amount=4897124.0
# Inserting: year=2021, quarter=1, state=madhya-pradesh, insurance_type=TOTAL, count=14427, amount=5567927.0
# Inserting: year=2021, quarter=2, state=madhya-pradesh, insurance_type=TOTAL, count=14803, amount=9787391.0
# Inserting: year=2021, quarter=3, state=madhya-pradesh, insurance_type=TOTAL, count=11990, amount=7806258.0
# Inserting: year=2021, quarter=4, state=madhya-pradesh, insurance_type=TOTAL, count=15069, amount=17524432.0
# Inserting: year=2022, quarter=1, state=madhya-pradesh, insurance_type=TOTAL, count=13791, amount=19901462.0
# Inserting: year=2022, quarter=2, state=madhya-pradesh, insurance_type=TOTAL, count=14629, amount=20159098.0
# Inserting: year=2022, quarter=3, state=madhya-pradesh, insurance_type=TOTAL, count=22733, amount=29185118.0
# Inserting: year=2022, quarter=4, state=madhya-pradesh, insurance_type=TOTAL, count=29234, amount=42712883.0
# Inserting: year=2023, quarter=1, state=madhya-pradesh, insurance_type=TOTAL, count=26393, amount=45135679.0
# Inserting: year=2023, quarter=2, state=madhya-pradesh, insurance_type=TOTAL, count=27027, amount=44871764.0
# Inserting: year=2023, quarter=3, state=madhya-pradesh, insurance_type=TOTAL, count=29300, amount=46963348.0
# Inserting: year=2023, quarter=4, state=madhya-pradesh, insurance_type=TOTAL, count=40784, amount=73801070.0
# Inserting: year=2024, quarter=1, state=madhya-pradesh, insurance_type=TOTAL, count=51223, amount=85215982.0
# Inserting: year=2024, quarter=2, state=madhya-pradesh, insurance_type=TOTAL, count=41429, amount=73836667.0
# Inserting: year=2024, quarter=3, state=madhya-pradesh, insurance_type=TOTAL, count=43248, amount=77995668.0
# Inserting: year=2024, quarter=4, state=madhya-pradesh, insurance_type=TOTAL, count=59688, amount=101096769.0
# Inserting: year=2020, quarter=2, state=maharashtra, insurance_type=TOTAL, count=39836, amount=6879717.0
# Inserting: year=2020, quarter=3, state=maharashtra, insurance_type=TOTAL, count=71662, amount=19230156.0
# Inserting: year=2020, quarter=4, state=maharashtra, insurance_type=TOTAL, count=44798, amount=27113814.0
# Inserting: year=2021, quarter=1, state=maharashtra, insurance_type=TOTAL, count=55792, amount=33137753.0
# Inserting: year=2021, quarter=2, state=maharashtra, insurance_type=TOTAL, count=70381, amount=46763103.0
# Inserting: year=2021, quarter=3, state=maharashtra, insurance_type=TOTAL, count=52268, amount=41313307.0
# Inserting: year=2021, quarter=4, state=maharashtra, insurance_type=TOTAL, count=82423, amount=93262227.0
# Inserting: year=2022, quarter=1, state=maharashtra, insurance_type=TOTAL, count=88015, amount=117411928.0
# Inserting: year=2022, quarter=2, state=maharashtra, insurance_type=TOTAL, count=80935, amount=104603934.0
# Inserting: year=2022, quarter=3, state=maharashtra, insurance_type=TOTAL, count=90958, amount=113835208.0
# Inserting: year=2022, quarter=4, state=maharashtra, insurance_type=TOTAL, count=125900, amount=174915648.0
# Inserting: year=2023, quarter=1, state=maharashtra, insurance_type=TOTAL, count=112174, amount=166596248.0
# Inserting: year=2023, quarter=2, state=maharashtra, insurance_type=TOTAL, count=102754, amount=157303399.0
# Inserting: year=2023, quarter=3, state=maharashtra, insurance_type=TOTAL, count=104872, amount=151171882.0
# Inserting: year=2023, quarter=4, state=maharashtra, insurance_type=TOTAL, count=136968, amount=217657114.0
# Inserting: year=2024, quarter=1, state=maharashtra, insurance_type=TOTAL, count=149016, amount=224725389.0
# Inserting: year=2024, quarter=2, state=maharashtra, insurance_type=TOTAL, count=118933, amount=198945046.0
# Inserting: year=2024, quarter=3, state=maharashtra, insurance_type=TOTAL, count=119776, amount=201319952.0
# Inserting: year=2024, quarter=4, state=maharashtra, insurance_type=TOTAL, count=168078, amount=266942711.0
# Inserting: year=2020, quarter=2, state=manipur, insurance_type=TOTAL, count=55, amount=12554.0
# Inserting: year=2020, quarter=3, state=manipur, insurance_type=TOTAL, count=134, amount=45164.0
# Inserting: year=2020, quarter=4, state=manipur, insurance_type=TOTAL, count=90, amount=49057.0
# Inserting: year=2021, quarter=1, state=manipur, insurance_type=TOTAL, count=136, amount=72254.0
# Inserting: year=2021, quarter=2, state=manipur, insurance_type=TOTAL, count=127, amount=81332.0
# Inserting: year=2021, quarter=3, state=manipur, insurance_type=TOTAL, count=111, amount=133016.0
# Inserting: year=2021, quarter=4, state=manipur, insurance_type=TOTAL, count=145, amount=271789.0
# Inserting: year=2022, quarter=1, state=manipur, insurance_type=TOTAL, count=177, amount=517854.0
# Inserting: year=2022, quarter=2, state=manipur, insurance_type=TOTAL, count=218, amount=553649.0
# Inserting: year=2022, quarter=3, state=manipur, insurance_type=TOTAL, count=200, amount=403213.0
# Inserting: year=2022, quarter=4, state=manipur, insurance_type=TOTAL, count=271, amount=620655.0
# Inserting: year=2023, quarter=1, state=manipur, insurance_type=TOTAL, count=222, amount=632084.0
# Inserting: year=2023, quarter=2, state=manipur, insurance_type=TOTAL, count=123, amount=341671.0
# Inserting: year=2023, quarter=3, state=manipur, insurance_type=TOTAL, count=76, amount=193021.0
# Inserting: year=2023, quarter=4, state=manipur, insurance_type=TOTAL, count=225, amount=476626.0
# Inserting: year=2024, quarter=1, state=manipur, insurance_type=TOTAL, count=385, amount=685052.0
# Inserting: year=2024, quarter=2, state=manipur, insurance_type=TOTAL, count=346, amount=647411.0
# Inserting: year=2024, quarter=3, state=manipur, insurance_type=TOTAL, count=285, amount=587893.0
# Inserting: year=2024, quarter=4, state=manipur, insurance_type=TOTAL, count=405, amount=826159.0
# Inserting: year=2020, quarter=2, state=meghalaya, insurance_type=TOTAL, count=41, amount=8829.0
# Inserting: year=2020, quarter=3, state=meghalaya, insurance_type=TOTAL, count=112, amount=33615.0
# Inserting: year=2020, quarter=4, state=meghalaya, insurance_type=TOTAL, count=92, amount=71029.0
# Inserting: year=2021, quarter=1, state=meghalaya, insurance_type=TOTAL, count=107, amount=128776.0
# Inserting: year=2021, quarter=2, state=meghalaya, insurance_type=TOTAL, count=139, amount=148434.0
# Inserting: year=2021, quarter=3, state=meghalaya, insurance_type=TOTAL, count=139, amount=214554.0
# Inserting: year=2021, quarter=4, state=meghalaya, insurance_type=TOTAL, count=263, amount=451612.0
# Inserting: year=2022, quarter=1, state=meghalaya, insurance_type=TOTAL, count=337, amount=729211.0
# Inserting: year=2022, quarter=2, state=meghalaya, insurance_type=TOTAL, count=379, amount=789094.0
# Inserting: year=2022, quarter=3, state=meghalaya, insurance_type=TOTAL, count=600, amount=1039491.0
# Inserting: year=2022, quarter=4, state=meghalaya, insurance_type=TOTAL, count=627, amount=1189529.0
# Inserting: year=2023, quarter=1, state=meghalaya, insurance_type=TOTAL, count=562, amount=1187523.0
# Inserting: year=2023, quarter=2, state=meghalaya, insurance_type=TOTAL, count=730, amount=1551577.0
# Inserting: year=2023, quarter=3, state=meghalaya, insurance_type=TOTAL, count=809, amount=1728076.0
# Inserting: year=2023, quarter=4, state=meghalaya, insurance_type=TOTAL, count=806, amount=1843364.0
# Inserting: year=2024, quarter=1, state=meghalaya, insurance_type=TOTAL, count=1030, amount=1987107.0
# Inserting: year=2024, quarter=2, state=meghalaya, insurance_type=TOTAL, count=1235, amount=2318007.0
# Inserting: year=2024, quarter=3, state=meghalaya, insurance_type=TOTAL, count=1140, amount=2443878.0
# Inserting: year=2024, quarter=4, state=meghalaya, insurance_type=TOTAL, count=1313, amount=2493656.0
# Inserting: year=2020, quarter=2, state=mizoram, insurance_type=TOTAL, count=31, amount=7322.0
# Inserting: year=2020, quarter=3, state=mizoram, insurance_type=TOTAL, count=74, amount=24691.0
# Inserting: year=2020, quarter=4, state=mizoram, insurance_type=TOTAL, count=81, amount=119124.0
# Inserting: year=2021, quarter=1, state=mizoram, insurance_type=TOTAL, count=415, amount=302841.0
# Inserting: year=2021, quarter=2, state=mizoram, insurance_type=TOTAL, count=187, amount=124805.0
# Inserting: year=2021, quarter=3, state=mizoram, insurance_type=TOTAL, count=81, amount=83641.0
# Inserting: year=2021, quarter=4, state=mizoram, insurance_type=TOTAL, count=100, amount=175847.0
# Inserting: year=2022, quarter=1, state=mizoram, insurance_type=TOTAL, count=85, amount=189428.0
# Inserting: year=2022, quarter=2, state=mizoram, insurance_type=TOTAL, count=76, amount=115090.0
# Inserting: year=2022, quarter=3, state=mizoram, insurance_type=TOTAL, count=310, amount=471306.0
# Inserting: year=2022, quarter=4, state=mizoram, insurance_type=TOTAL, count=350, amount=612551.0
# Inserting: year=2023, quarter=1, state=mizoram, insurance_type=TOTAL, count=171, amount=326688.0
# Inserting: year=2023, quarter=2, state=mizoram, insurance_type=TOTAL, count=119, amount=232928.0
# Inserting: year=2023, quarter=3, state=mizoram, insurance_type=TOTAL, count=166, amount=271799.0
# Inserting: year=2023, quarter=4, state=mizoram, insurance_type=TOTAL, count=312, amount=557950.0
# Inserting: year=2024, quarter=1, state=mizoram, insurance_type=TOTAL, count=277, amount=427693.0
# Inserting: year=2024, quarter=2, state=mizoram, insurance_type=TOTAL, count=214, amount=331455.0
# Inserting: year=2024, quarter=3, state=mizoram, insurance_type=TOTAL, count=186, amount=275746.0
# Inserting: year=2024, quarter=4, state=mizoram, insurance_type=TOTAL, count=489, amount=811687.0
# Inserting: year=2020, quarter=2, state=nagaland, insurance_type=TOTAL, count=41, amount=9791.0
# Inserting: year=2020, quarter=3, state=nagaland, insurance_type=TOTAL, count=89, amount=20798.0
# Inserting: year=2020, quarter=4, state=nagaland, insurance_type=TOTAL, count=62, amount=38836.0
# Inserting: year=2021, quarter=1, state=nagaland, insurance_type=TOTAL, count=79, amount=42973.0
# Inserting: year=2021, quarter=2, state=nagaland, insurance_type=TOTAL, count=85, amount=139479.0
# Inserting: year=2021, quarter=3, state=nagaland, insurance_type=TOTAL, count=91, amount=123643.0
# Inserting: year=2021, quarter=4, state=nagaland, insurance_type=TOTAL, count=183, amount=341424.0
# Inserting: year=2022, quarter=1, state=nagaland, insurance_type=TOTAL, count=242, amount=529223.0
# Inserting: year=2022, quarter=2, state=nagaland, insurance_type=TOTAL, count=186, amount=380878.0
# Inserting: year=2022, quarter=3, state=nagaland, insurance_type=TOTAL, count=210, amount=439669.0
# Inserting: year=2022, quarter=4, state=nagaland, insurance_type=TOTAL, count=367, amount=700864.0
# Inserting: year=2023, quarter=1, state=nagaland, insurance_type=TOTAL, count=320, amount=704957.0
# ...
# Inserting: year=2024, quarter=2, state=punjab, insurance_type=TOTAL, count=14129, amount=27164397.0
# Inserting: year=2024, quarter=3, state=punjab, insurance_type=TOTAL, count=15509, amount=30111034.0
# Inserting: year=2024, quarter=4, state=punjab, insurance_type=TOTAL, count=16279, amount=31878987.0
# Inserting: year=2020, quarter=2, state=rajasthan, insurance_type=TOTAL, count=5373, amount=1095933.0
# Inserting: year=2020, quarter=3, state=rajasthan, insurance_type=TOTAL, count=15235, amount=3758527.0
# Inserting: year=2020, quarter=4, state=rajasthan, insurance_type=TOTAL, count=12509, amount=6471573.0
# Inserting: year=2021, quarter=1, state=rajasthan, insurance_type=TOTAL, count=17800, amount=8074225.0
# Inserting: year=2021, quarter=2, state=rajasthan, insurance_type=TOTAL, count=18281, amount=14357445.0
# Inserting: year=2021, quarter=3, state=rajasthan, insurance_type=TOTAL, count=16643, amount=12793862.0
# Inserting: year=2021, quarter=4, state=rajasthan, insurance_type=TOTAL, count=19375, amount=24455262.0
# Inserting: year=2022, quarter=1, state=rajasthan, insurance_type=TOTAL, count=21517, amount=31576932.0
# Inserting: year=2022, quarter=2, state=rajasthan, insurance_type=TOTAL, count=24333, amount=33748931.0
# Inserting: year=2022, quarter=3, state=rajasthan, insurance_type=TOTAL, count=33975, amount=45565544.0
# Inserting: year=2022, quarter=4, state=rajasthan, insurance_type=TOTAL, count=40926, amount=60792838.0
# Inserting: year=2023, quarter=1, state=rajasthan, insurance_type=TOTAL, count=34415, amount=61441050.0
# Inserting: year=2023, quarter=2, state=rajasthan, insurance_type=TOTAL, count=37170, amount=61301449.0
# Inserting: year=2023, quarter=3, state=rajasthan, insurance_type=TOTAL, count=39960, amount=64328784.0
# Inserting: year=2023, quarter=4, state=rajasthan, insurance_type=TOTAL, count=49741, amount=94701652.0
# Inserting: year=2024, quarter=1, state=rajasthan, insurance_type=TOTAL, count=59127, amount=102926410.0
# Inserting: year=2024, quarter=2, state=rajasthan, insurance_type=TOTAL, count=55241, amount=95504657.0
# Inserting: year=2024, quarter=3, state=rajasthan, insurance_type=TOTAL, count=64533, amount=108827800.0
# Inserting: year=2024, quarter=4, state=rajasthan, insurance_type=TOTAL, count=73530, amount=127930986.0
# Inserting: year=2020, quarter=2, state=sikkim, insurance_type=TOTAL, count=21, amount=4789.0
# Inserting: year=2020, quarter=3, state=sikkim, insurance_type=TOTAL, count=94, amount=28000.0
# Inserting: year=2020, quarter=4, state=sikkim, insurance_type=TOTAL, count=67, amount=70214.0
# Inserting: year=2021, quarter=1, state=sikkim, insurance_type=TOTAL, count=122, amount=111777.0
# Inserting: year=2021, quarter=2, state=sikkim, insurance_type=TOTAL, count=93, amount=122064.0
# Inserting: year=2021, quarter=3, state=sikkim, insurance_type=TOTAL, count=106, amount=140552.0
# Inserting: year=2021, quarter=4, state=sikkim, insurance_type=TOTAL, count=195, amount=503532.0
# Inserting: year=2022, quarter=1, state=sikkim, insurance_type=TOTAL, count=239, amount=685987.0
# Inserting: year=2022, quarter=2, state=sikkim, insurance_type=TOTAL, count=160, amount=383709.0
# Inserting: year=2022, quarter=3, state=sikkim, insurance_type=TOTAL, count=243, amount=474940.0
# Inserting: year=2022, quarter=4, state=sikkim, insurance_type=TOTAL, count=306, amount=667214.0
# Inserting: year=2023, quarter=1, state=sikkim, insurance_type=TOTAL, count=260, amount=688605.0
# Inserting: year=2023, quarter=2, state=sikkim, insurance_type=TOTAL, count=270, amount=628191.0
# Inserting: year=2023, quarter=3, state=sikkim, insurance_type=TOTAL, count=251, amount=698251.0
# Inserting: year=2023, quarter=4, state=sikkim, insurance_type=TOTAL, count=324, amount=793745.0
# Inserting: year=2024, quarter=1, state=sikkim, insurance_type=TOTAL, count=400, amount=880182.0
# Inserting: year=2024, quarter=2, state=sikkim, insurance_type=TOTAL, count=685, amount=1590554.0
# Inserting: year=2024, quarter=3, state=sikkim, insurance_type=TOTAL, count=461, amount=1029398.0
# Inserting: year=2024, quarter=4, state=sikkim, insurance_type=TOTAL, count=599, amount=1381680.0
# Inserting: year=2020, quarter=2, state=tamil-nadu, insurance_type=TOTAL, count=5473, amount=1075552.0
# Inserting: year=2020, quarter=3, state=tamil-nadu, insurance_type=TOTAL, count=8026, amount=2257373.0
# Inserting: year=2020, quarter=4, state=tamil-nadu, insurance_type=TOTAL, count=10290, amount=8993575.0
# Inserting: year=2021, quarter=1, state=tamil-nadu, insurance_type=TOTAL, count=14406, amount=11180849.0
# Inserting: year=2021, quarter=2, state=tamil-nadu, insurance_type=TOTAL, count=17682, amount=16444344.0
# Inserting: year=2021, quarter=3, state=tamil-nadu, insurance_type=TOTAL, count=23107, amount=23402918.0
# Inserting: year=2021, quarter=4, state=tamil-nadu, insurance_type=TOTAL, count=33037, amount=42184290.0
# Inserting: year=2022, quarter=1, state=tamil-nadu, insurance_type=TOTAL, count=47621, amount=64969045.0
# Inserting: year=2022, quarter=2, state=tamil-nadu, insurance_type=TOTAL, count=46714, amount=61835120.0
# Inserting: year=2022, quarter=3, state=tamil-nadu, insurance_type=TOTAL, count=64356, amount=79747520.0
# Inserting: year=2022, quarter=4, state=tamil-nadu, insurance_type=TOTAL, count=125491, amount=146457790.0
# Inserting: year=2023, quarter=1, state=tamil-nadu, insurance_type=TOTAL, count=90690, amount=116710222.0
# Inserting: year=2023, quarter=2, state=tamil-nadu, insurance_type=TOTAL, count=79698, amount=105328191.0
# Inserting: year=2023, quarter=3, state=tamil-nadu, insurance_type=TOTAL, count=91069, amount=114625593.0
# Inserting: year=2023, quarter=4, state=tamil-nadu, insurance_type=TOTAL, count=104871, amount=139433796.0
# Inserting: year=2024, quarter=1, state=tamil-nadu, insurance_type=TOTAL, count=111521, amount=148976175.0
# Inserting: year=2024, quarter=2, state=tamil-nadu, insurance_type=TOTAL, count=97348, amount=135972378.0
# Inserting: year=2024, quarter=3, state=tamil-nadu, insurance_type=TOTAL, count=116867, amount=162128271.0
# Inserting: year=2024, quarter=4, state=tamil-nadu, insurance_type=TOTAL, count=127002, amount=173784251.0
# Inserting: year=2020, quarter=2, state=telangana, insurance_type=TOTAL, count=19003, amount=3419453.0
# Inserting: year=2020, quarter=3, state=telangana, insurance_type=TOTAL, count=34395, amount=8406543.0
# Inserting: year=2020, quarter=4, state=telangana, insurance_type=TOTAL, count=20961, amount=11339099.0
# Inserting: year=2021, quarter=1, state=telangana, insurance_type=TOTAL, count=28298, amount=14810947.0
# Inserting: year=2021, quarter=2, state=telangana, insurance_type=TOTAL, count=28870, amount=20935651.0
# Inserting: year=2021, quarter=3, state=telangana, insurance_type=TOTAL, count=27080, amount=20925217.0
# Inserting: year=2021, quarter=4, state=telangana, insurance_type=TOTAL, count=34848, amount=38845492.0
# Inserting: year=2022, quarter=1, state=telangana, insurance_type=TOTAL, count=36325, amount=51942016.0
# Inserting: year=2022, quarter=2, state=telangana, insurance_type=TOTAL, count=45600, amount=58056956.0
# Inserting: year=2022, quarter=3, state=telangana, insurance_type=TOTAL, count=51465, amount=64798126.0
# Inserting: year=2022, quarter=4, state=telangana, insurance_type=TOTAL, count=64655, amount=88544127.0
# Inserting: year=2023, quarter=1, state=telangana, insurance_type=TOTAL, count=54508, amount=82678207.0
# Inserting: year=2023, quarter=2, state=telangana, insurance_type=TOTAL, count=55118, amount=79238968.0
# Inserting: year=2023, quarter=3, state=telangana, insurance_type=TOTAL, count=61523, amount=84397465.0
# Inserting: year=2023, quarter=4, state=telangana, insurance_type=TOTAL, count=63993, amount=105605522.0
# Inserting: year=2024, quarter=1, state=telangana, insurance_type=TOTAL, count=67388, amount=105607539.0
# Inserting: year=2024, quarter=2, state=telangana, insurance_type=TOTAL, count=56941, amount=96037304.0
# Inserting: year=2024, quarter=3, state=telangana, insurance_type=TOTAL, count=64873, amount=110715264.0
# Inserting: year=2024, quarter=4, state=telangana, insurance_type=TOTAL, count=78498, amount=124755619.0
# Inserting: year=2020, quarter=2, state=tripura, insurance_type=TOTAL, count=88, amount=22054.0
# Inserting: year=2020, quarter=3, state=tripura, insurance_type=TOTAL, count=249, amount=61642.0
# Inserting: year=2020, quarter=4, state=tripura, insurance_type=TOTAL, count=244, amount=149765.0
# Inserting: year=2021, quarter=1, state=tripura, insurance_type=TOTAL, count=360, amount=191531.0
# Inserting: year=2021, quarter=2, state=tripura, insurance_type=TOTAL, count=381, amount=409934.0
# Inserting: year=2021, quarter=3, state=tripura, insurance_type=TOTAL, count=494, amount=649961.0
# Inserting: year=2021, quarter=4, state=tripura, insurance_type=TOTAL, count=702, amount=1022508.0
# Inserting: year=2022, quarter=1, state=tripura, insurance_type=TOTAL, count=907, amount=1493401.0
# Inserting: year=2022, quarter=2, state=tripura, insurance_type=TOTAL, count=1021, amount=1509105.0
# Inserting: year=2022, quarter=3, state=tripura, insurance_type=TOTAL, count=1590, amount=2105984.0
# Inserting: year=2022, quarter=4, state=tripura, insurance_type=TOTAL, count=1508, amount=2112534.0
# Inserting: year=2023, quarter=1, state=tripura, insurance_type=TOTAL, count=1642, amount=2404958.0
# Inserting: year=2023, quarter=2, state=tripura, insurance_type=TOTAL, count=1563, amount=2163813.0
# Inserting: year=2023, quarter=3, state=tripura, insurance_type=TOTAL, count=2071, amount=2899393.0
# Inserting: year=2023, quarter=4, state=tripura, insurance_type=TOTAL, count=2237, amount=3169741.0
# Inserting: year=2024, quarter=1, state=tripura, insurance_type=TOTAL, count=2637, amount=3417568.0
# Inserting: year=2024, quarter=2, state=tripura, insurance_type=TOTAL, count=2188, amount=2869489.0
# Inserting: year=2024, quarter=3, state=tripura, insurance_type=TOTAL, count=2516, amount=3323343.0
# Inserting: year=2024, quarter=4, state=tripura, insurance_type=TOTAL, count=2794, amount=3765732.0
# Inserting: year=2020, quarter=2, state=uttar-pradesh, insurance_type=TOTAL, count=9884, amount=1912266.0
# Inserting: year=2020, quarter=3, state=uttar-pradesh, insurance_type=TOTAL, count=18131, amount=4436969.0
# Inserting: year=2020, quarter=4, state=uttar-pradesh, insurance_type=TOTAL, count=17470, amount=14180417.0
# Inserting: year=2021, quarter=1, state=uttar-pradesh, insurance_type=TOTAL, count=24103, amount=18027573.0
# Inserting: year=2021, quarter=2, state=uttar-pradesh, insurance_type=TOTAL, count=25952, amount=25137571.0
# Inserting: year=2021, quarter=3, state=uttar-pradesh, insurance_type=TOTAL, count=32799, amount=32641118.0
# Inserting: year=2021, quarter=4, state=uttar-pradesh, insurance_type=TOTAL, count=44132, amount=59654951.0
# Inserting: year=2022, quarter=1, state=uttar-pradesh, insurance_type=TOTAL, count=45996, amount=73014969.0
# Inserting: year=2022, quarter=2, state=uttar-pradesh, insurance_type=TOTAL, count=55133, amount=77434953.0
# Inserting: year=2022, quarter=3, state=uttar-pradesh, insurance_type=TOTAL, count=64514, amount=87703512.0
# Inserting: year=2022, quarter=4, state=uttar-pradesh, insurance_type=TOTAL, count=77022, amount=116755813.0
# Inserting: year=2023, quarter=1, state=uttar-pradesh, insurance_type=TOTAL, count=73080, amount=127110494.0
# Inserting: year=2023, quarter=2, state=uttar-pradesh, insurance_type=TOTAL, count=74194, amount=122522457.0
# Inserting: year=2023, quarter=3, state=uttar-pradesh, insurance_type=TOTAL, count=78940, amount=121483170.0
# Inserting: year=2023, quarter=4, state=uttar-pradesh, insurance_type=TOTAL, count=92125, amount=165509877.0
# Inserting: year=2024, quarter=1, state=uttar-pradesh, insurance_type=TOTAL, count=103701, amount=176442664.0
# Inserting: year=2024, quarter=2, state=uttar-pradesh, insurance_type=TOTAL, count=92458, amount=159894258.0
# Inserting: year=2024, quarter=3, state=uttar-pradesh, insurance_type=TOTAL, count=92930, amount=157303596.0
# Inserting: year=2024, quarter=4, state=uttar-pradesh, insurance_type=TOTAL, count=116589, amount=199179867.0
# Inserting: year=2020, quarter=2, state=uttarakhand, insurance_type=TOTAL, count=660, amount=134899.0
# Inserting: year=2020, quarter=3, state=uttarakhand, insurance_type=TOTAL, count=1403, amount=418543.0
# Inserting: year=2020, quarter=4, state=uttarakhand, insurance_type=TOTAL, count=1756, amount=1961891.0
# Inserting: year=2021, quarter=1, state=uttarakhand, insurance_type=TOTAL, count=2607, amount=2719327.0
# Inserting: year=2021, quarter=2, state=uttarakhand, insurance_type=TOTAL, count=2742, amount=3265717.0
# Inserting: year=2021, quarter=3, state=uttarakhand, insurance_type=TOTAL, count=4111, amount=4646571.0
# Inserting: year=2021, quarter=4, state=uttarakhand, insurance_type=TOTAL, count=5529, amount=7849020.0
# Inserting: year=2022, quarter=1, state=uttarakhand, insurance_type=TOTAL, count=5339, amount=8824948.0
# Inserting: year=2022, quarter=2, state=uttarakhand, insurance_type=TOTAL, count=5773, amount=9168313.0
# Inserting: year=2022, quarter=3, state=uttarakhand, insurance_type=TOTAL, count=6784, amount=10070172.0
# Inserting: year=2022, quarter=4, state=uttarakhand, insurance_type=TOTAL, count=8750, amount=13817747.0
# Inserting: year=2023, quarter=1, state=uttarakhand, insurance_type=TOTAL, count=7552, amount=13599026.0
# Inserting: year=2023, quarter=2, state=uttarakhand, insurance_type=TOTAL, count=8051, amount=14034915.0
# Inserting: year=2023, quarter=3, state=uttarakhand, insurance_type=TOTAL, count=7856, amount=12636749.0
# Inserting: year=2023, quarter=4, state=uttarakhand, insurance_type=TOTAL, count=10040, amount=19045152.0
# Inserting: year=2024, quarter=1, state=uttarakhand, insurance_type=TOTAL, count=11533, amount=19531483.0
# Inserting: year=2024, quarter=2, state=uttarakhand, insurance_type=TOTAL, count=10311, amount=17754447.0
# Inserting: year=2024, quarter=3, state=uttarakhand, insurance_type=TOTAL, count=10487, amount=17860144.0
# Inserting: year=2024, quarter=4, state=uttarakhand, insurance_type=TOTAL, count=13090, amount=23367549.0
# Inserting: year=2020, quarter=2, state=west-bengal, insurance_type=TOTAL, count=7619, amount=1432764.0
# Inserting: year=2020, quarter=3, state=west-bengal, insurance_type=TOTAL, count=12596, amount=2878482.0
# Inserting: year=2020, quarter=4, state=west-bengal, insurance_type=TOTAL, count=10233, amount=7510455.0
# Inserting: year=2021, quarter=1, state=west-bengal, insurance_type=TOTAL, count=15488, amount=11172042.0
# Inserting: year=2021, quarter=2, state=west-bengal, insurance_type=TOTAL, count=15200, amount=12396029.0
# Inserting: year=2021, quarter=3, state=west-bengal, insurance_type=TOTAL, count=24839, amount=21424337.0
# Inserting: year=2021, quarter=4, state=west-bengal, insurance_type=TOTAL, count=26320, amount=31282871.0
# Inserting: year=2022, quarter=1, state=west-bengal, insurance_type=TOTAL, count=38779, amount=51160527.0
# Inserting: year=2022, quarter=2, state=west-bengal, insurance_type=TOTAL, count=33542, amount=41737021.0
# Inserting: year=2022, quarter=3, state=west-bengal, insurance_type=TOTAL, count=47853, amount=59092307.0
# Inserting: year=2022, quarter=4, state=west-bengal, insurance_type=TOTAL, count=54277, amount=70466433.0
# Inserting: year=2023, quarter=1, state=west-bengal, insurance_type=TOTAL, count=56833, amount=77461732.0
# Inserting: year=2023, quarter=2, state=west-bengal, insurance_type=TOTAL, count=49792, amount=65204280.0
# Inserting: year=2023, quarter=3, state=west-bengal, insurance_type=TOTAL, count=58131, amount=76359312.0
# Inserting: year=2023, quarter=4, state=west-bengal, insurance_type=TOTAL, count=72712, amount=100365562.0
# Inserting: year=2024, quarter=1, state=west-bengal, insurance_type=TOTAL, count=79576, amount=104987909.0
# Inserting: year=2024, quarter=2, state=west-bengal, insurance_type=TOTAL, count=67048, amount=89476633.0
# Inserting: year=2024, quarter=3, state=west-bengal, insurance_type=TOTAL, count=77158, amount=107451766.0
# Inserting: year=2024, quarter=4, state=west-bengal, insurance_type=TOTAL, count=91719, amount=120602777.0
# aggregated_insurance inserted.
